# %%
#import libraries and packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

df = pd.read_csv('cleanmath.csv')
df
# Out:
#        Unnamed: 0  STU_ID  X2SEX  X2RACE  X2SESQ5  X2TXMQUINT  X2MTHID  \
# 0               0   10001      1       8        5           5     0.16
# 1               1   10002      2       8        2           4    -0.42
# 2               2   10003      2       3        5           4    -1.54
# 3               3   10007      2       8        4           2     0.12
# 4               4   10009      1       8        4           5     0.70
# ...           ...     ...    ...     ...      ...         ...      ...
# 16213       16213   35200      1       8        5           5     1.82
# 16214       16214   35203      2       5        1           3    -0.42
# 16215       16215   35204      2       8        3           3    -0.42
# 16216       16216   35205      1       8        5           3    -1.54
# 16217       16217   35206      2       8        5           5     1.82
#
#        X2MTHUTI  X2MTHEFF  X2MTHINT_R
# 0          1.21      1.73       -0.21
# ...

# %%
ax = sns.boxplot(x='X2MTHID', y='X2TXMQUINT', data=df)
#Math identity and math scores showed a 0.4 correlation. 
#A boxplot was used to further explore this relationship.

# %%
#Group 1: High identity, low scores = Over confident ---> 
#created a subset of 204 falsely confident folks
df_OC = df[(df['X2MTHID']>=1.28) & (df['X2TXMQUINT'] <= 2)]
df_OC

#H1: My hypothesis is that there will be more boys in group 1 (overconfident).
# Out:
#        Unnamed: 0  STU_ID  X2SEX  X2RACE  X2SESQ5  X2TXMQUINT  X2MTHID  \
# 22             22   10039      2       2        4           1     1.82
# 70             70   10121      1       6        5           2     1.28
# 115           115   10192      1       7        2           2     1.82
# 253           253   10402      1       3        5           1     1.82
# 342           342   10543      1       8        2           2     1.82
# ...           ...     ...    ...     ...      ...         ...      ...
# 15938       15938   34773      1       5        3           2     1.28
# 16031       16031   34928      2       8        1           1     1.28
# 16076       16076   34997      1       3        4           1     1.82
# 16079       16079   35005      2       2        4           2     1.28
# 16099       16099   35036      1       8        3           2     1.82
#
#        X2MTHUTI  X2MTHEFF  X2MTHINT_R
# 22         1.21      0.32        0.48
# ...

# %%
#Group 2: High scores, low identity = Under confident ---> created a subset of 187 not confident folks
df_UC = df[(df['X2MTHID'] <= -1.5) & (df['X2TXMQUINT'] == 5)]
df_UC
#H2: My hypothesis is that there will be more girls in group 2 (underrconfident).
# Out:
#        Unnamed: 0  STU_ID  X2SEX  X2RACE  X2SESQ5  X2TXMQUINT  X2MTHID  \
# 138           138   10220      1       8        1           5    -1.54
# 247           247   10392      2       6        5           5    -1.54
# 254           254   10404      1       8        5           5    -1.54
# 436           436   10674      2       6        5           5    -1.54
# 439           439   10678      2       8        5           5    -1.54
# ...           ...     ...    ...     ...      ...         ...      ...
# 15844       15844   34610      1       8        5           5    -1.54
# 15874       15874   34668      2       8        4           5    -1.54
# 15886       15886   34690      2       8        4           5    -1.54
# 15912       15912   34735      1       8        4           5    -1.54
# 16000       16000   34881      2       8        2           5    -1.54
#
#        X2MTHUTI  X2MTHEFF  X2MTHINT_R
# 138       -2.47     -2.50       -1.89
# ...

# %%
#Group 3: High scores and high identity ----> created a subset of 1012 high performers/believers.
df_HP = df[(df['X2MTHID']>1.8) & (df['X2TXMQUINT'] == 5)]
df_HP
#H3: My hypothesis is that there will be an equal number of boys and girls in group 3 (high perfomers/believers).
# Out:
#        Unnamed: 0  STU_ID  X2SEX  X2RACE  X2SESQ5  X2TXMQUINT  X2MTHID  \
# 27             27   10049      2       5        4           5     1.82
# 40             40   10069      1       2        5           5     1.82
# 66             66   10112      1       2        5           5     1.82
# 76             76   10131      1       5        5           5     1.82
# 101           101   10170      1       2        4           5     1.82
# ...           ...     ...    ...     ...      ...         ...      ...
# 16174       16174   35150      2       8        5           5     1.82
# 16178       16178   35154      2       8        3           5     1.82
# 16184       16184   35160      2       5        1           5     1.82
# 16213       16213   35200      1       8        5           5     1.82
# 16217       16217   35206      2       8        5           5     1.82
#
#        X2MTHUTI  X2MTHEFF  X2MTHINT_R
# 27         1.21      0.32        1.38
# ...

# %%
df_HP.describe()
# Out:
#          Unnamed: 0        STU_ID        X2SEX       X2RACE      X2SESQ5  \
# count   1012.000000   1012.000000  1012.000000  1012.000000  1012.000000
# mean    8067.927866  22490.919960     1.413043     6.256917     3.970356
# std     4662.858796   7245.241906     0.492624     2.411890     1.259233
# min       27.000000  10049.000000     1.000000     1.000000     1.000000
# 25%     4071.750000  16277.250000     1.000000     5.000000     3.000000
# 50%     7925.000000  22252.500000     1.000000     8.000000     4.000000
# 75%    11994.500000  28570.500000     2.000000     8.000000     5.000000
# max    16217.000000  35206.000000     2.000000     8.000000     5.000000
#
#        X2TXMQUINT       X2MTHID     X2MTHUTI     X2MTHEFF   X2MTHINT_R
# count      1012.0  1.012000e+03  1012.000000  1012.000000  1012.000000
# mean          5.0  1.820000e+00     0.869990     1.132500     1.191324
# std           0.0  1.599512e-14     0.561621     0.701985     0.803715
# ...

# %%
df_HP.value_counts('X2SEX')
#H3: While there are more boys than girls, a T-test will show if there is a significant difference.
# Out:
# X2SEX
# 1    594
# 2    418
# dtype: int64

# %%
df_OC.describe()
# Out:
#          Unnamed: 0        STU_ID       X2SEX      X2RACE     X2SESQ5  \
# count    204.000000    204.000000  204.000000  204.000000  204.000000
# mean    8486.465686  23141.808824    1.470588    5.681373    2.794118
# std     4840.318839   7517.942425    0.500362    2.226452    1.392013
# min       22.000000  10039.000000    1.000000    1.000000    1.000000
# 25%     4132.250000  16371.250000    1.000000    3.000000    1.750000
# 50%     8899.500000  23792.500000    1.000000    6.000000    3.000000
# 75%    12861.250000  29908.250000    2.000000    8.000000    4.000000
# max    16099.000000  35036.000000    2.000000    8.000000    5.000000
#
#        X2TXMQUINT     X2MTHID    X2MTHUTI    X2MTHEFF  X2MTHINT_R
# count  204.000000  204.000000  204.000000  204.000000  204.000000
# mean     1.676471    1.737941    0.766618    0.948382    0.941667
# std      0.468974    0.194328    0.825651    0.868166    0.973376
# min      1.000000    1.280000   -3.940000   -2.500000   -1.890000
# ...

# %%
df_OC.value_counts('X2SEX')
# Out:
# X2SEX
# 1    108
# 2     96
# dtype: int64

# %%
df_OC.value_counts('X2SESQ5')
# Out:
# X2SESQ5
# 1    51
# 3    45
# 2    39
# 4    39
# 5    30
# dtype: int64

# %%
df_UC.describe()
# Out:
#          Unnamed: 0        STU_ID       X2SEX      X2RACE     X2SESQ5  \
# count    187.000000    187.000000  187.000000  187.000000  187.000000
# mean    8285.711230  22829.481283    1.657754    6.647059    3.989305
# std     4953.019428   7695.870194    0.475735    2.133584    1.261461
# min      138.000000  10220.000000    1.000000    1.000000    1.000000
# 25%     3787.500000  15864.000000    1.000000    5.000000    3.000000
# 50%     8216.000000  22720.000000    2.000000    8.000000    5.000000
# 75%    13073.000000  30237.500000    2.000000    8.000000    5.000000
# max    16000.000000  34881.000000    2.000000    8.000000    5.000000
#
#        X2TXMQUINT  X2MTHID    X2MTHUTI    X2MTHEFF  X2MTHINT_R
# count       187.0   187.00  187.000000  187.000000  187.000000
# mean          5.0    -1.54   -0.763316   -0.636043   -0.879144
# std           0.0     0.00    1.105421    1.028623    0.716824
# min           5.0    -1.54   -3.940000   -2.500000   -1.890000
# ...

# %%
df_UC.value_counts('X2SEX')
# Out:
# X2SEX
# 2    123
# 1     64
# dtype: int64

# %%
df_UC.value_counts('X2SESQ5')
# Out:
# X2SESQ5
# 5    94
# 4    40
# 2    23
# 3    20
# 1    10
# dtype: int64
